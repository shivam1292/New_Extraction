# %%
import requests
from bs4 import BeautifulSoup

# %%
# !pip install gtts
# Out:
# Requirement already satisfied: gtts in /usr/local/lib/python3.11/dist-packages (2.5.4)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from gtts) (2.32.3)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.11/dist-packages (from gtts) (8.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->gtts) (2025.1.31)

# %%
import requests
from bs4 import BeautifulSoup
from textblob import TextBlob
from googletrans import Translator
from gtts import gTTS
import os
import json
from collections import Counter

# %%
def get_yahoo_news(company, max_articles=10):
    search_url = f'https://news.search.yahoo.com/search?p={company}'#This is base URL of yahoo
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(search_url, headers=headers)
    if response.status_code != 200: #This line is justfying that we can extract the data from website
        return [] #To avoid crashing

    soup = BeautifulSoup(response.text, 'html.parser') #To convert raw HTML from response.text into a structured format like titles, links, and summaries from web pages
    articles = []

    for item in soup.find_all('div', class_='NewsArticle', limit=max_articles):
        title_tag = item.find('h4')
        summary_tag = item.find('p')
        meta_tag = item.find('span', class_='s-source')

        if title_tag and summary_tag:
            articles.append({
                'Title': title_tag.text.strip(),

                'Summary': summary_tag.text.strip(),

            })
    return articles

# %%
def fetch_news(company):
    yahoo_news = get_yahoo_news(company)
    all_news =  yahoo_news
    return all_news

# %%
fetch_news("Tesla")
# Out:
# [{'Title': 'Tesla Vandalism Sparked by Fury Against Musk Draws GOP Criticism',
#   'Summary': '(Bloomberg) -- Molotov cocktails at Tesla showrooms. Disturbing messages on Cybertrucks. Vandalism...'},
#  {'Title': '1 Wall Street Analyst Thinks Tesla Will Hit $425. Is it a Buy Around $235?',
#   'Summary': 'Tesla (NASDAQ: TSLA) has long been a battleground stock, but recently, the fight between bulls and...'},
#  {'Title': 'Jimmy Kimmel Mocks Tesla for Cybertruck Recall, Roasts the Conservatives...',
#   'Summary': 'Jimmy Kimmel isn’t letting Elon Musk off the hook. The same goes for the conservatives who are...'},
#  {'Title': 'Trump suggests Tesla vandals be jailed in El Salvador',
#   'Summary': 'President Donald Trump suggested Friday that people who vandalize Tesla property -- the car brand...'},
#  {'Title': 'Trump goes to bat for Tesla as backlash, financial woes escalate',
#   'Summary': 'The White House is going to bat for Tesla as Elon Musk’s electric vehicle (EV) company suffers from...'},
#  {'Title': 'Tesla faces a ‘brand crisis tornado.’ The one guy who can fix it is MIA | CNN...',
#   'Summary': 'A version of this story appeared in CNN Business’ Nightcap newsletter. Elon Musk seems to be...'},
#  {'Title': "Tesla workers in Germany say they don't have time to use the bathroom",
#   'Summary': 'Tesla workers in Germany are asking for better working conditions and more breaks. The petition...'},
#  {'Title': "Why one of Wall Street's biggest Tesla bulls is getting cautious",
#   'Summary': "The Tesla (TSLA) stock rout appears to have shaken one of Wall Street's biggest bulls on the name...."},
#  {'Title': "Hiltzik: Why Tesla's bumpy ride may not be over",
#   'Summary': "President Trump promoting Tesla cars on the White House lawn on March 11. (Associated Press) It wasn't that long ago — Dec. 17, in fact — that Tesla..."},
#  {'Title': 'Tesla attacks mark a surreal twist in political violence as Musk divides America',
#   'Summary': 'A member of the Seattle Fire Department inspects a burned Tesla Cybertruck at a Tesla lot in Seattle...'}]

# %%
# Step 2: Sentiment Analysis
def analyze_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity
    return ("Positive" if polarity > 0.05 else "Negative" if polarity < -0.05 else "Neutral", polarity)

# %%
# Step 3: Comparative Sentiment Analysis
def comparative_sentiment_analysis(news_articles):
    sentiment_results = [analyze_sentiment(article["Summary"])[0] for article in news_articles]
    sentiment_counts = Counter(sentiment_results)

    return {
        "Sentiment Distribution": sentiment_counts,
        "Coverage Differences": [
            {
                "Comparison": "Some articles are positive while others discuss challenges.",
                "Impact": "Positive news boosts investor confidence, while negative news may cause concerns."
            }
        ]
    }

# %%
# Step 4: Translate Text to Hindi
def translate_to_hindi(text):
    translator = Translator()
    return translator.translate(text, src="en", dest="hi").text

# %%
# Step 5: Convert to Speech
def text_to_speech_hindi(text, filename="news_audio.mp3"):
    tts = gTTS(text=text, lang="hi")
    tts.save(filename)
    # os.system(f"start {filename}")  # For Windows
    return filename

# %%
# Main Execution (One-Time Input)
company_name = input("Enter the company name: ")
news_articles = fetch_news(company_name)

for article in news_articles:
    sentiment, score = analyze_sentiment(article["Summary"])
    article["Sentiment"] = sentiment
# Out:
# Enter the company name: Tesla

# %%
# Convert news summaries to Hindi
hindi_summaries = [translate_to_hindi(article["Summary"]) for article in news_articles]
speech_text = " ".join(hindi_summaries)
speech_file = text_to_speech_hindi(speech_text)

# %%
# Final JSON Output
final_output = {
    "Company": company_name,
    "Articles": news_articles,
    "Comparative Sentiment Score": comparative_results,
    "Final Sentiment Analysis": "Overall, the news coverage is mixed.",
    "Audio": speech_file
}

print("\n✅ JSON Output:")
print(json.dumps(final_output, indent=4, ensure_ascii=False))
# Out:
# ✅ JSON Output:
# {
#     "Company": "Tesla",
#     "Articles": [
#         {
#             "Title": "Tesla Vandalism Sparked by Fury Against Musk Draws GOP Criticism",
#             "Summary": "(Bloomberg) -- Molotov cocktails at Tesla showrooms. Disturbing messages on Cybertrucks. Vandalism...",
#             "Sentiment": "Negative"
#         },
#         {
#             "Title": "1 Wall Street Analyst Thinks Tesla Will Hit $425. Is it a Buy Around $235?",
#             "Summary": "Tesla (NASDAQ: TSLA) has long been a battleground stock, but recently, the fight between bulls and...",
#             "Sentiment": "Neutral"
#         },
#         {
#             "Title": "Jimmy Kimmel Mocks Tesla for Cybertruck Recall, Roasts the Conservatives...",
#             "Summary": "Jimmy Kimmel isn’t letting Elon Musk off the hook. The same goes for the conservatives who are...",
#             "Sentiment": "Neutral"
#         },
#         {
#             "Title": "Trump suggests Tesla vandals be jailed in El Salvador",
#             "Summary": "President Donald Trump suggested Friday that people who vandalize Tesla property -- the car brand...",
#             "Sentiment": "Neutral"
#         },
#         {
#             "Title": "Trump goes to bat for Tesla as backlash, financial woes escalate",
#             "Summary": "The White House is going to bat for Tesla as Elon Musk’s electric vehicle (EV) company suffers from...",
#             "Sentiment": "Negative"
#         },
#         {
#             "Title": "Tesla faces a ‘brand crisis tornado.’ The one guy who can fix it is MIA | CNN...",
#             "Summary": "A version of this story appeared in CNN Business’ Nightcap newsletter. Elon Musk seems to be...",
#             "Sentiment": "Neutral"
#         },
#         {
#             "Title": "Tesla workers in Germany say they don't have time to use the bathroom",
#             "Summary": "Tesla workers in Germany are asking for better working conditions and more breaks. The petition...",
#             "Sentiment": "Positive"
#         },
#         {
#             "Title": "Why one of Wall Street's biggest Tesla bulls is getting cautious",
#             "Summary": "The Tesla (TSLA) stock rout appears to have shaken one of Wall Street's biggest bulls on the name....",
#             "Sentiment": "Neutral"
#         },
#         {
#             "Title": "Hiltzik: Why Tesla's bumpy ride may not be over",
#             "Summary": "President Trump promoting Tesla cars on the White House lawn on March 11. (Associated Press) It wasn't that long ago — Dec. 17, in fact — that Tesla...",
#             "Sentiment": "Neutral"
#         },
#         {
#             "Title": "Tesla attacks mark a surreal twist in political violence as Musk divides America",
#             "Summary": "A member of the Seattle Fire Department inspects a burned Tesla Cybertruck at a Tesla lot in Seattle...",
#             "Sentiment": "Neutral"
#         }
#     ],
#     "Comparative Sentiment Score": {
#         "Sentiment Distribution": {
#             "Negative": 2,
#             "Neutral": 7,
#             "Positive": 1
#         },
#         "Coverage Differences": [
#             {
#                 "Comparison": "Some articles are positive while others discuss challenges.",
#                 "Impact": "Positive news boosts investor confidence, while negative news may cause concerns."
#             }
#         ]
#     },
#     "Final Sentiment Analysis": "Overall, the news coverage is mixed.",
#     "Audio": "news_audio.mp3"
# }

# %%
import requests
from bs4 import BeautifulSoup
from textblob import TextBlob
from googletrans import Translator
from gtts import gTTS
import os
import json
from collections import Counter
from IPython.display import Audio

# Step 1: Fetch News from Yahoo
def get_yahoo_news(company, max_articles=10):
    """Fetches news articles from Yahoo News for a given company."""
    search_url = f'https://news.search.yahoo.com/search?p={company}'
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(search_url, headers=headers)

    if response.status_code != 200:
        return []  # Avoid crashing

    soup = BeautifulSoup(response.text, 'html.parser')
    articles = []

    for item in soup.find_all('div', class_='NewsArticle', limit=max_articles):
        title_tag = item.find('h4')
        summary_tag = item.find('p')

        if title_tag and summary_tag:
            articles.append({
                'Title': title_tag.text.strip(),
                'Summary': summary_tag.text.strip(),
            })

    return articles

# Step 2: Perform Sentiment Analysis
def analyze_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity
    return "Positive" if polarity > 0.05 else "Negative" if polarity < -0.05 else "Neutral"

# Step 3: Comparative Sentiment Analysis
def comparative_sentiment_analysis(news_articles):
    sentiment_results = [analyze_sentiment(article["Summary"]) for article in news_articles]
    sentiment_counts = Counter(sentiment_results)

    return {
        "Sentiment Distribution": sentiment_counts,
        "Coverage Differences": [
            {
                "Comparison": "Some articles are positive while others discuss challenges.",
                "Impact": "Positive news boosts investor confidence, while negative news may cause concerns."
            }
        ]
    }

# Step 4: Translate Text to Hindi
def translate_to_hindi(text):
    translator = Translator()
    return translator.translate(text, src="en", dest="hi").text

# Step 5: Convert Hindi Text to Speech
def text_to_speech_hindi(text, filename="news_audio.mp3"):
    tts = gTTS(text=text, lang="hi")
    tts.save(filename)
    return filename

# 🚀 **Main Execution (Single Input)**
company_name = input("Enter the company name: ")
print("\nFetching News, Performing Sentiment Analysis, Translating to Hindi, and Generating Speech...\n")

news_articles = get_yahoo_news(company_name)

# Process each article (Sentiment Analysis + Translation)
hindi_summaries = []
for article in news_articles:
    article["Sentiment"] = analyze_sentiment(article["Summary"])
    hindi_summary = translate_to_hindi(article["Summary"])
    hindi_summaries.append(hindi_summary)

# Perform Comparative Sentiment Analysis
comparative_results = comparative_sentiment_analysis(news_articles)

# Convert all summaries into Hindi speech
speech_text = " ".join(hindi_summaries)
speech_file = text_to_speech_hindi(speech_text)

# Final JSON Output
final_output = {
    "Company": company_name,
    "Articles": news_articles,
    "Comparative Sentiment Score": comparative_results,
    "Final Sentiment Analysis": "Overall, the news coverage is mixed.",
    "Audio": speech_file
}

# Print JSON Output
print("\n✅ JSON Output:")
print(json.dumps(final_output, indent=4, ensure_ascii=False))

# Play Hindi Speech
print("\n🎙 Playing Hindi Speech...")
Audio(speech_file, autoplay=True)
# Out:
# Enter the company name: Tesla
#
# Fetching News, Performing Sentiment Analysis, Translating to Hindi, and Generating Speech...
#
#
# ✅ JSON Output:
# {
#     "Company": "Tesla",
#     "Articles": [
#         {
#             "Title": "Tesla Trade-Ins Rise as Brand Sentiment Slips Amid Political Backlash",
#             "Summary": "A record number of Tesla (TSLA, Financials) owners traded in their electric vehicles for models from...",
#             "Sentiment": "Neutral"
#         },
#         {
#             "Title": "Tesla Stock Is Up: All-Hands Meeting, Musk at the Pentagon, Trade-Ins, and Price...",
#             "Summary": "Tesla has a budding brand problem. The question for investors is whether CEO Elon Musk will realize...",
#             "Sentiment": "Positive"
#         },
#         {
#             "Title": "Tesla's Elon Musk holds surprise all-hands meeting to assuage employees and...",
#             "Summary": "Tesla CEO Elon Musk held an impromptu company all-hands Thursday night, giving an update on the...",
#             "Sentiment": "Neutral"
#         },
#         {
#             "Title": "Tesla Vandalism Sparked by Fury Against Musk Draws GOP Ire",
#             "Summary": "(Bloomberg) -- Molotov cocktails at Tesla showrooms. Disturbing messages on Cybertrucks. Vandalism...",
#             "Sentiment": "Negative"
#         },
#         {
#             "Title": "Quiet quitting? Tesla owners trading in vehicles at record pace",
#             "Summary": "People protesting Elon Musk's actions in the Trump administration hold signs outside a Tesla...",
#             "Sentiment": "Neutral"
#         },
#         {
#             "Title": "People are ditching their Teslas in huge numbers as the Elon Musk backlash grows",
#             "Summary": "New data from the U.S. car-shopping site Edmunds points to a growing shift in consumer sentiment...",
#             "Sentiment": "Positive"
#         },
#         {
#             "Title": "Tesla Trade-Ins Are At An All-Time High, Edmunds Says",
#             "Summary": "As Tesla CEO Elon Musk implores his employees not to sell their stock even though “it feels like...",
#             "Sentiment": "Neutral"
#         },
#         {
#             "Title": "Tesla’s Retail Fans Buy the Stock at a Pace Never Seen Before",
#             "Summary": "(Bloomberg) -- Tesla Inc.’s stock is in a freefall. Its sales are plunging around the world. Even...",
#             "Sentiment": "Neutral"
#         },
#         {
#             "Title": "Fargo Tesla charging station fire suspected to be arson | The Mary Sue",
#             "Summary": "It's not a great time to be a Tesla owner.",
#             "Sentiment": "Negative"
#         },
#         {
#             "Title": "Elon Musk's surprise all-hands brings Tesla's biggest bull back from the brink",
#             "Summary": "Tesla investors have expressed concern that Elon Musk is spending too much time on DOGE.Samuel...",
#             "Sentiment": "Positive"
#         }
#     ],
#     "Comparative Sentiment Score": {
#         "Sentiment Distribution": {
#             "Neutral": 5,
#             "Positive": 3,
#             "Negative": 2
#         },
#         "Coverage Differences": [
#             {
#                 "Comparison": "Some articles are positive while others discuss challenges.",
#                 "Impact": "Positive news boosts investor confidence, while negative news may cause concerns."
#             }
#         ]
#     },
#     "Final Sentiment Analysis": "Overall, the news coverage is mixed.",
#     "Audio": "news_audio.mp3"
# }
#
# 🎙 Playing Hindi Speech...
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
